# %%
import dlc2kinematics
import pandas as pd

# %%
pwd
# Out:
# '/Users/eduardosaman/Desktop'

# %%
df, bodyparts, scorer = dlc2kinematics.load_data('/Users/eduardosaman/Desktop/RESULTS/sf/sfv1/dsfs4_v1DLC_resnet50_ZebrafishNet2.0Apr28shuffle1_25000_filtered.h5')
df_vel = dlc2kinematics.compute_velocity(df,bodyparts=['all'])
df_acc = dlc2kinematics.compute_acceleration(df,bodyparts=['all'])
df_speed = dlc2kinematics.compute_speed(df,bodyparts=['Head'])
df_acc.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv1/acceleration.csv', index=True)
df_speed.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv1/speed.csv', index=True)
df_vel.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv1/velocity.csv', index=True)

# %%
df, bodyparts, scorer = dlc2kinematics.load_data('/Users/eduardosaman/Desktop/RESULTS/sf/sfv2/dsfs4_v2DLC_resnet50_ZebrafishNet2.0Apr28shuffle1_25000_filtered.h5')
df_vel = dlc2kinematics.compute_velocity(df,bodyparts=['all'])
df_acc = dlc2kinematics.compute_acceleration(df,bodyparts=['all'])
df_speed = dlc2kinematics.compute_speed(df,bodyparts=['Head'])
df_acc.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv2/acceleration.csv', index=True)
df_speed.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv2/speed.csv', index=True)
df_vel.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv2/velocity.csv', index=True)

# %%
df, bodyparts, scorer = dlc2kinematics.load_data('/Users/eduardosaman/Desktop/RESULTS/sf/sfv3/dsfs4_v3DLC_resnet50_ZebrafishNet2.0Apr28shuffle1_25000_filtered.h5')
df_vel = dlc2kinematics.compute_velocity(df,bodyparts=['all'])
df_acc = dlc2kinematics.compute_acceleration(df,bodyparts=['all'])
df_speed = dlc2kinematics.compute_speed(df,bodyparts=['Head'])
df_acc.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv3/acceleration.csv', index=True)
df_speed.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv3/speed.csv', index=True)
df_vel.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv3/velocity.csv', index=True)

# %%
df, bodyparts, scorer = dlc2kinematics.load_data('/Users/eduardosaman/Desktop/RESULTS/sf/sfv4/dsfs4_v4DLC_resnet50_ZebrafishNet2.0Apr28shuffle1_25000_filtered.h5')
df_vel = dlc2kinematics.compute_velocity(df,bodyparts=['all'])
df_acc = dlc2kinematics.compute_acceleration(df,bodyparts=['all'])
df_speed = dlc2kinematics.compute_speed(df,bodyparts=['Head'])
df_acc.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv4/acceleration.csv', index=True)
df_speed.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv4/speed.csv', index=True)
df_vel.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv4/velocity.csv', index=True)

# %%
df, bodyparts, scorer = dlc2kinematics.load_data('/Users/eduardosaman/Desktop/RESULTS/sf/sfv5/dsfs4_v5DLC_resnet50_ZebrafishNet2.0Apr28shuffle1_25000_filtered.h5')
df_vel = dlc2kinematics.compute_velocity(df,bodyparts=['all'])
df_acc = dlc2kinematics.compute_acceleration(df,bodyparts=['all'])
df_speed = dlc2kinematics.compute_speed(df,bodyparts=['Head'])
df_acc.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv5/acceleration.csv', index=True)
df_speed.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv5/speed.csv', index=True)
df_vel.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv5/velocity.csv', index=True)

# %%
df, bodyparts, scorer = dlc2kinematics.load_data('/Users/eduardosaman/Desktop/RESULTS/sf/sfv6/dsfs4_v6DLC_resnet50_ZebrafishNet2.0Apr28shuffle1_25000_filtered.h5')
df_vel = dlc2kinematics.compute_velocity(df,bodyparts=['all'])
df_acc = dlc2kinematics.compute_acceleration(df,bodyparts=['all'])
df_speed = dlc2kinematics.compute_speed(df,bodyparts=['Head'])
df_acc.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv6/acceleration.csv', index=True)
df_speed.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv6/speed.csv', index=True)
df_vel.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv6/velocity.csv', index=True)

# %%
df, bodyparts, scorer = dlc2kinematics.load_data('/Users/eduardosaman/Desktop/RESULTS/sf/sfv7/dsfs4_v7DLC_resnet50_ZebrafishNet2.0Apr28shuffle1_25000_filtered.h5')
df_vel = dlc2kinematics.compute_velocity(df,bodyparts=['all'])
df_acc = dlc2kinematics.compute_acceleration(df,bodyparts=['all'])
df_speed = dlc2kinematics.compute_speed(df,bodyparts=['Head'])
df_acc.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv7/acceleration.csv', index=True)
df_speed.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv7/speed.csv', index=True)
df_vel.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv7/velocity.csv', index=True)

# %%
df, bodyparts, scorer = dlc2kinematics.load_data('/Users/eduardosaman/Desktop/RESULTS/sf/sfv8/dsfs4_v8DLC_resnet50_ZebrafishNet2.0Apr28shuffle1_25000_filtered.h5')
df_vel = dlc2kinematics.compute_velocity(df,bodyparts=['all'])
df_acc = dlc2kinematics.compute_acceleration(df,bodyparts=['all'])
df_speed = dlc2kinematics.compute_speed(df,bodyparts=['Head'])
df_acc.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv8/acceleration.csv', index=True)
df_speed.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv8/speed.csv', index=True)
df_vel.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv8/velocity.csv', index=True)

# %%
df, bodyparts, scorer = dlc2kinematics.load_data('/Users/eduardosaman/Desktop/RESULTS/sf/sfv9/dsfs4_v9DLC_resnet50_ZebrafishNet2.0Apr28shuffle1_25000_filtered.h5')
df_vel = dlc2kinematics.compute_velocity(df,bodyparts=['all'])
df_acc = dlc2kinematics.compute_acceleration(df,bodyparts=['all'])
df_speed = dlc2kinematics.compute_speed(df,bodyparts=['Head'])
df_acc.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv9/acceleration.csv', index=True)
df_speed.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv9/speed.csv', index=True)
df_vel.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv9/velocity.csv', index=True)

# %%
df, bodyparts, scorer = dlc2kinematics.load_data('/Users/eduardosaman/Desktop/RESULTS/sf/sfv10/dsfs4_v10DLC_resnet50_ZebrafishNet2.0Apr28shuffle1_25000_filtered.h5')
df_vel = dlc2kinematics.compute_velocity(df,bodyparts=['all'])
df_acc = dlc2kinematics.compute_acceleration(df,bodyparts=['all'])
df_speed = dlc2kinematics.compute_speed(df,bodyparts=['Head'])
df_acc.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv10/acceleration.csv', index=True)
df_speed.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv10/speed.csv', index=True)
df_vel.to_csv('/Users/eduardosaman/Desktop/RESULTS/sf/sfv10/velocity.csv', index=True)
