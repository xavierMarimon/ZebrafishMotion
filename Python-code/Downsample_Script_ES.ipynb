# %%
import moviepy.editor as mp

# %%
clip1 = mp.VideoFileClip("sf3s5_v1.mp4")
clip1_resized = clip1.resize(height=480) # make the height 480 ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
clip1_resized.write_videofile("dsf3s5_v1.mp4")
# Out:
# Moviepy - Building video dsf3s5_v1.mp4.
# Moviepy - Writing video dsf3s5_v1.mp4
# Moviepy - Done !
# Moviepy - video ready dsf3s5_v1.mp4

# %%
clip2 = mp.VideoFileClip("sf3s5_v2.mp4")
clip2_resized = clip2.resize(height=480) # make the height 480 ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
clip2_resized.write_videofile("dsf3s5_v2.mp4")
# Out:
# Moviepy - Building video dsf3s5_v2.mp4.
# Moviepy - Writing video dsf3s5_v2.mp4
# Moviepy - Done !
# Moviepy - video ready dsf3s5_v2.mp4

# %%
clip3 = mp.VideoFileClip("sf3s5_v3.mp4")
clip3_resized = clip3.resize(height=480) # make the height 480 ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
clip3_resized.write_videofile("dsf3s5_v3.mp4")
# Out:
# Moviepy - Building video dsf3s5_v3.mp4.
# Moviepy - Writing video dsf3s5_v3.mp4
# Moviepy - Done !
# Moviepy - video ready dsf3s5_v3.mp4

# %%
clip4 = mp.VideoFileClip("sf3s5_v4.mp4")
clip4_resized = clip4.resize(height=480) # make the height 480 ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
clip4_resized.write_videofile("dsf3s5_v4.mp4")
# Out:
# Moviepy - Building video dsf3s5_v4.mp4.
# Moviepy - Writing video dsf3s5_v4.mp4
# Moviepy - Done !
# Moviepy - video ready dsf3s5_v4.mp4

# %%
clip5 = mp.VideoFileClip("sf3s5_v5.mp4")
clip5_resized = clip5.resize(height=480) # make the height 480 ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
clip5_resized.write_videofile("dsf3s5_v5.mp4")
# Out:
# Moviepy - Building video dsf3s5_v5.mp4.
# Moviepy - Writing video dsf3s5_v5.mp4
# Moviepy - Done !
# Moviepy - video ready dsf3s5_v5.mp4

# %%
clip6 = mp.VideoFileClip("sf3s5_v6.mp4")
clip6_resized = clip6.resize(height=480) # make the height 480 ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
clip6_resized.write_videofile("dsf3s5_v6.mp4")
# Out:
# Moviepy - Building video dsf3s5_v6.mp4.
# Moviepy - Writing video dsf3s5_v6.mp4
# Moviepy - Done !
# Moviepy - video ready dsf3s5_v6.mp4

# %%
clip7 = mp.VideoFileClip("sf3s5_v7.mp4")
clip7_resized = clip7.resize(height=480) # make the height 480 ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
clip7_resized.write_videofile("dsf3s5_v7.mp4")
# Out:
# Moviepy - Building video dsf3s5_v7.mp4.
# Moviepy - Writing video dsf3s5_v7.mp4
# Moviepy - Done !
# Moviepy - video ready dsf3s5_v7.mp4

# %%
clip8 = mp.VideoFileClip("sf3s5_v8.mp4")
clip8_resized = clip8.resize(height=480) # make the height 480 ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
clip8_resized.write_videofile("dsf3s5_v8.mp4")
# Out:
# Moviepy - Building video dsf3s5_v8.mp4.
# Moviepy - Writing video dsf3s5_v8.mp4
# Moviepy - Done !
# Moviepy - video ready dsf3s5_v8.mp4

# %%
clip9 = mp.VideoFileClip("sf3s5_v9.mp4")
clip9_resized = clip9.resize(height=480) # make the height 480 ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
clip9_resized.write_videofile("dsf3s5_v9.mp4")
# Out:
# Moviepy - Building video dsf3s5_v9.mp4.
# Moviepy - Writing video dsf3s5_v9.mp4
# Moviepy - Done !
# Moviepy - video ready dsf3s5_v9.mp4

# %%
clip10 = mp.VideoFileClip("sf3s5_v10.mp4")
clip10_resized = clip10.resize(height=480) # make the height 480 ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
clip10_resized.write_videofile("dsf3s5_v10.mp4")
# Out:
# Moviepy - Building video dsf3s5_v10.mp4.
# Moviepy - Writing video dsf3s5_v10.mp4
# Moviepy - Done !
# Moviepy - video ready dsf3s5_v10.mp4
