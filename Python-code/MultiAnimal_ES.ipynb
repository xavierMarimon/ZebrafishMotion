# %%
import deeplabcut
# Out:
# /home/ge86sof2/.local/lib/python3.8/site-packages/statsmodels/compat/pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)
# /home/ge86sof2/miniconda3/envs/DeepLabCut/lib/python3.8/site-packages/deeplabcut/__init__.py:78: UserWarning:
#         As PyTorch is not installed, unsupervised identity learning will not be available.
#         Please run `pip install torch`, or ignore this warning.
#
#   warnings.warn(

# %%
#SKIP IF ALREADY CREATED
deeplabcut.create_new_project('','EduardoSaman', ['/home/ge86sof2/','/home/ge86sof2/'], working_directory='/home/ge86sof2', copy_videos=
True)

# %%
#VERIFY
config_path = ('/home/ge86sof2/MultiZebrafish-EduardoSaman-2022-05-05/config.yaml')

# %%
#SKIP IF DONE
deeplabcut.extract_frames(config_path,'automatic','kmeans',crop=False, userfeedback=False)

# %%
#START TRAINING FROM HERE
deeplabcut.create_multianimaltraining_dataset(config_path, paf_graph='config')

# %%
deeplabcut.train_network(config_path, shuffle=1, trainingsetindex=0, gputouse=1, max_snapshots_to_keep=5, autotune=False, displayiters=10, saveiters=5000, maxiters=30000, allow_growth=True)

# %%
deeplabcut.evaluate_network(config_path, plotting=True)
# Out:
# Running  DLC_dlcrnetms5_MultiZebrafishMay5shuffle1_10000  with # of trainingiterations: 10000
# /home/ge86sof2/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# /home/ge86sof2/.local/lib/python3.8/site-packages/tf_slim/layers/layers.py:684: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   outputs = layer.apply(inputs, training=is_training)
# Activating extracting of PAFs

# %%
deeplabcut.extract_save_all_maps(config_path, shuffle=1, Indices=[0, 5])

# %%
scorername = deeplabcut.analyze_videos(config_path,['/home/ge86sof2/Results_Two/d2fs3_v2/d2fs3_v2.mp4'], videotype='.mp4')

# %%
new_vid = ['/home/ge86sof2/Results_Two/d2fs3_v2/d2fs3_v2.mp4']
deeplabcut.analyze_videos(config_path, new_vid, videotype='.mp4', shuffle =1, save_as_csv=True)

deeplabcut.filterpredictions(config_path, new_vid, videotype='.mp4', shuffle=1)

deeplabcut.plot_trajectories(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

deeplabcut.create_labeled_video(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

# %%
new_vid = ['/home/ge86sof2/Results_S3/sf/sfv2/dsfs4_v2.mp4']
deeplabcut.analyze_videos(config_path, new_vid, videotype='.mp4', shuffle =1, save_as_csv=True)

deeplabcut.filterpredictions(config_path, new_vid, videotype='.mp4', shuffle=1)

deeplabcut.plot_trajectories(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

deeplabcut.create_labeled_video(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

# %%
new_vid = ['/home/ge86sof2/Results_S3/sf/sfv3/dsfs4_v3.mp4']
deeplabcut.analyze_videos(config_path, new_vid, videotype='.mp4', shuffle =1, save_as_csv=True)

deeplabcut.filterpredictions(config_path, new_vid, videotype='.mp4', shuffle=1)

deeplabcut.plot_trajectories(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

deeplabcut.create_labeled_video(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

# %%
new_vid = ['/home/ge86sof2/Results_S3/sf/sfv4/dsfs4_v4.mp4']
deeplabcut.analyze_videos(config_path, new_vid, videotype='.mp4', shuffle =1, save_as_csv=True)

deeplabcut.filterpredictions(config_path, new_vid, videotype='.mp4', shuffle=1)

deeplabcut.plot_trajectories(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

deeplabcut.create_labeled_video(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

# %%
new_vid = ['/home/ge86sof2/Results_S3/sf/sfv5/dsfs4_v5.mp4']
deeplabcut.analyze_videos(config_path, new_vid, videotype='.mp4', shuffle =1, save_as_csv=True)

deeplabcut.filterpredictions(config_path, new_vid, videotype='.mp4', shuffle=1)

deeplabcut.plot_trajectories(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

deeplabcut.create_labeled_video(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

# %%
new_vid = ['/home/ge86sof2/Results_S3/sf/sfv6/dsfs4_v6.mp4']
deeplabcut.analyze_videos(config_path, new_vid, videotype='.mp4', shuffle =1, save_as_csv=True)

deeplabcut.filterpredictions(config_path, new_vid, videotype='.mp4', shuffle=1)

deeplabcut.plot_trajectories(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

deeplabcut.create_labeled_video(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

# %%
new_vid = ['/home/ge86sof2/Results_S3/sf/sfv7/dsfs4_v7.mp4']
deeplabcut.analyze_videos(config_path, new_vid, videotype='.mp4', shuffle =1, save_as_csv=True)

deeplabcut.filterpredictions(config_path, new_vid, videotype='.mp4', shuffle=1)

deeplabcut.plot_trajectories(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

deeplabcut.create_labeled_video(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

# %%
new_vid = ['/home/ge86sof2/Results_S3/sf/sfv8/dsfs4_v8.mp4']
deeplabcut.analyze_videos(config_path, new_vid, videotype='.mp4', shuffle =1, save_as_csv=True)

deeplabcut.filterpredictions(config_path, new_vid, videotype='.mp4', shuffle=1)

deeplabcut.plot_trajectories(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

deeplabcut.create_labeled_video(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

# %%
new_vid = ['/home/ge86sof2/Results_S3/sf/sfv9/dsfs4_v9.mp4']
deeplabcut.analyze_videos(config_path, new_vid, videotype='.mp4', shuffle =1, save_as_csv=True)

deeplabcut.filterpredictions(config_path, new_vid, videotype='.mp4', shuffle=1)

deeplabcut.plot_trajectories(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

deeplabcut.create_labeled_video(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

# %%
new_vid = ['/home/ge86sof2/Results_S3/sf/sfv10/dsfs4_v10.mp4']
deeplabcut.analyze_videos(config_path, new_vid, videotype='.mp4', shuffle =1, save_as_csv=True)

deeplabcut.filterpredictions(config_path, new_vid, videotype='.mp4', shuffle=1)

deeplabcut.plot_trajectories(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)

deeplabcut.create_labeled_video(config_path, new_vid, videotype='.mp4', shuffle=1, filtered=True)
